# %%
# %matplotlib inline

# %%
import cvxopt as opt
from cvxopt import blas, solvers

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# let's put together some random assets and try to optimize a portfolio

# %%
# number of assets
n_assets = 4

# number of observations
n_obs = 1000

# %%
return_vec = np.random.randn(n_assets, n_obs)

# %%
# show the plot of the normally distributed returns
plt.plot(return_vec.T)
plt.tight_layout()
